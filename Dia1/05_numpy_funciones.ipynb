# %% [markdown]
# # funciones mas comunies en numpy

# %%
import numpy as np

# %% [markdown]
# #SHAPER Y RESHAPE

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[4, 6],
#        [3, 5],
#        [8, 6]])

# %%
arr.shape
# Out:
# (3, 2)

# %%
arr.ndim
# Out:
# 2

# %%
arr.reshape(1,6)
# Out:
# array([[4, 6, 3, 5, 8, 6]])

# %%
arr.ndim
# Out:
# 2

# %% [markdown]
# #funciones estadisticas MAX Y ARGMAX

# %%
arr = np.random.randint(1,10,(3,2))
arr
# Out:
# array([[5, 2],
#        [4, 4],
#        [8, 5]])

# %%
matriz = arr.reshape(1,6)
matriz
matriz
# Out:
# array([[5, 2, 4, 4, 8, 5]])

# %%
arr.max()
# Out:
# 8

# %%
matriz.max()
# Out:
# 8

# %%
matriz.max(1)
# Out:
# array([8])

# %%
arr.argmax()
# Out:
# 4

# %% [markdown]
# #MIN Y ARGMIN

# %%
arr.min()
# Out:
# 2

# %%
arr.argmin()
# Out:
# 1

# %%
matriz.min(0)
# Out:
# array([5, 2, 4, 4, 8, 5])

# %% [markdown]
# ## sort, ordenar

# %%
arr
# Out:
# array([[5, 2],
#        [4, 4],
#        [8, 5]])

# %%
arr.sort()
arr
# Out:
# array([[2, 5],
#        [4, 4],
#        [5, 8]])

# %% [markdown]
# #mediana

# %%
np.median(arr)
# Out:
# 4.5

# %% [markdown]
# ## DESVIACION ESTANDAR

# %%
np.std(arr)
# Out:
# 1.7950549357115013

# %% [markdown]
# ##VARIANZA

# %%
np.var(arr)
# Out:
# 3.222222222222222
